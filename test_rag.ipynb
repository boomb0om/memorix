# %%
import os
from pathlib import Path
from typing import List

from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_qdrant import QdrantVectorStore
from langchain_huggingface import HuggingFaceEmbeddings

from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

# %%
def get_embedder():
    # Мультиязычный SOTA-эмбеддер
    model_name = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
    return HuggingFaceEmbeddings(model_name=model_name)


def init_qdrant(collection="lectures", host="http://localhost:6333"):
    client = QdrantClient(url=host)

    if collection not in [c.name for c in client.get_collections().collections]:
        client.create_collection(
            collection_name=collection,
            vectors_config=VectorParams(size=768, distance=Distance.COSINE)
        )
    return client

# %%
collection = "lectures"

embedder = get_embedder()
client = init_qdrant(collection)

# %%
qdrant = QdrantVectorStore(
    client=client,
    collection_name=collection,
    embedding=embedder,
)

# %%
topic = "Определитель матрицы - это"

docs = qdrant.similarity_search(topic, k=10)
for doc in docs:
    print(doc.page_content)
    print(doc.metadata)
    print("-" * 100)
# Out:
# Составим и вычислим определитель матрицы системы:
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 14, 'page_label': '15', '_id': '4db67acc-5532-481f-b0de-f2c6e31af906', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
#  Матрицы, имеющие одинаковое число строк и число столбцов, а
# также равные соответствующие элементы, называются равными.  Матрица может содержать только один столбец, тогда она
# называется матрицей-столбцом, или только одну строку, тогда она
# называется матрицей-строкой:
#  1 3 8 2С  . Вообще говоря, матрица
# может состоять даже из одного элемента. Действия над матрицами
# Над матрицами, как и над числами, можно производить ряд операций,
# причем некоторые из них аналогичны операциям над числами, а нек оторые –
# специфические. 1. Суммой (разностью)  двух матриц одинаковой размерности называется
# матрица, элементы которой равны сумме (разности) соответствующих
# элементов матриц слагаемых. Например:
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
#  
# 1279
# 132
# 307
# 321
# 972
# 213 . 2.Произведением матрицы на число называется матрица, полученная из
# данной умножением всех ее элементов на число. Например:
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 6921
# 31512
# 603
# 237
# 154
# 201
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 2, 'page_label': '3', '_id': '21cc10e0-5d7c-48ed-b0db-f170137a9180', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# 5
#
# 2. Определители квадратных матриц, их основные свойства
# Определитель – число, характеризующее квадратную матрицу. Он
# определен только для квадратных матриц. Для неквадратных матриц
# определитель не вычисляется (т.е. не существует) .Определитель матрицы А
# обозначается
# А  или
#  , или
# ()det A . Определителем матрицы первого порядка
#  11A а , или определителем
# первого порядка, называется элемент
# 11а :
# 111 аА  . Под определителем (детерминантом) второго порядка понимается
# выражение
# 21122211
# 2221
# 1211
# аааааа
# аа 
# . (1.1)
# Пример 1.2. Вычислить матрицы
# 25
# 64А  . Решение.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 4, 'page_label': '5', '_id': '8fbea387-0db7-4593-b128-0242349fb826', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# 4
#
# Тогда произведением матрицназывается такая матрица С , каждый элемент
# которой сij равен сумме произведений элементов i-й строки матрицы А на
# соответствующие элементы j-го столбца матрицы В. Пример 1.1.Пусть
# 1 0 1
# 2 1 0A  ,
# 01
# 10
# 22
# B
# 
#  . Найти произведение
# матрицАВ. Решение.Умножение матрицы А на матрицу В определено, т.к. число
# столбцов первой матрицы  (3) равно числу строк второй  (3). Тогдапроизведение матрицАВ примет вид:
#        
#    
# 01 1 0 0 1 1 2 1 1 0 0 1 21 0 1 10 2 0 1 1 0 2 2 1 1 0 0 22 1 0 22
# 23
# 12
# AB
#                                     
#  
# Отметим, что АВ
#  ВА. 4.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 3, 'page_label': '4', '_id': 'efc389f5-440b-4028-84f0-e7fe7e842871', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# Возведение в степень. Целой положительной степенью
#  1тАт 
# квадратной матрицы А называется произведение т матриц, рав ных А, т.е. 23 ,A A A A A A A    
# . Заметим, что операция возведения в степень
# определяется только для квадратных матриц. 5. Транспонирование матрицы – переход от матрицы А к матрице
# TА ,в
# которой строки и столбцы поменялись местами с со хранением по рядка. Из
# определения следует, что если матрица А имеет размер
# тп , то
# транспонированная матрица
# TА имеет размер
# пт . Например, пусть
# 160
# 4 5 1A   , тогда
# 14160 654 5 1 01
# T
# TA
#       
# .
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 3, 'page_label': '4', '_id': '3cd36c93-c5bd-4c32-99cd-f22b3fc9ea52', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# 2
#
# Так, у матрицы А – 2 строки и 2 столбца, а матрица В содержит 2
# строки и 3 столбца. Разновидности матриц
#  Если у матрицы одинаковое число строк и столбцов, ее называют
# квадратной. Главной диагональю квадратной матрицы  называют элементы,
# имеющие одинаковые индексы, тоесть те элементы, у которых номе р строки
# совпадает с номером столбца. Это элементы
# 11 22,,aa  .Побочная диагональ
# идет «перпендикулярно» главной диагонали.  Матрица  называется прямоугольной, если количество ее строк
# не совпадает с количеством столбцов.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 1, 'page_label': '2', '_id': 'bab921f3-85b3-476f-ad40-f870107bf637', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# данной умножением всех ее элементов на число. Например:
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 6921
# 31512
# 603
# 237
# 154
# 201
# 3 – все элементы матрицы
# умножаются на число 3. 3. Умножение матриц. Умножение матрицы А на матрицу В
# определено, когда число столбцов первой матрицы равно числу строк второй.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 2, 'page_label': '3', '_id': 'c4048c2d-730b-4134-83ae-38eb9bcce4d2', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# Какое число называется определителем 1-го, 2-го и 3-го порядка? 10. Что называется минором и алгебраическим дополнением элемента
# матрицы? 11.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 11, 'page_label': '12', '_id': '9ca90f27-f694-4ae9-8f50-2fd4c4bff19c', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# 12
#
# 7. Какие действия можно выполнять с матрицами? 8. Что является основной числовой характеристикой квадратной
# матрицы? 9.
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 11, 'page_label': '12', '_id': '35782897-1810-472e-ae74-4b50caedfb13', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
# тп , называется прямоугольная
# таблица чисел, содержащая m строк и n столбцов. Числа, составляющие
# матрицу, называются элементами матрицы. Место каждого элемента
# однозначно определяется номером строки и столбца, на пересечении которых
# он находится. Элементы матрицы обозначаются
# ija , где i- номер строки, а j-
# номер столбца. Матрицы обычно обозначают з аглавными буквами
# латинского алфавита:
# 11 12 1
# 21 22 2
# 13
# ... ...
# {'producer': 'Microsoft® Office Word 2007', 'creator': 'Microsoft® Office Word 2007', 'creationdate': 'D:20201014090602', 'author': 'user', 'moddate': 'D:20201014090602', 'source': 'docs/4309_f_41_matematika-1-kurs.pdf', 'total_pages': 180, 'page': 0, 'page_label': '1', '_id': '760eeaee-84d9-4f41-baf5-f0c4332766e8', '_collection_name': 'lectures'}
# ----------------------------------------------------------------------------------------------------
